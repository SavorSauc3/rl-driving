# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = 'CarRacing-v2'
env = gym.make(environment_name, render_mode='human')

# %%
env.close()

# %%
env = gym.make(environment_name, render_mode='human')
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, info, frame = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode,score))

env.close()

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training\Logs\PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 58   |
# |    iterations      | 1    |
# |    time_elapsed    | 35   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 2           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005374728 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.263       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00446    |
# |    std                  | 0.997       |
# |    value_loss           | 0.699       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 3           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007774705 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.225       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00899    |
# |    std                  | 0.991       |
# |    value_loss           | 0.581       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 4           |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007980423 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00989    |
# |    std                  | 0.988       |
# |    value_loss           | 0.63        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 43           |
# |    iterations           | 5            |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0065052174 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.31         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.177        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00635     |
# |    std                  | 0.976        |
# |    value_loss           | 0.613        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 6           |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011898429 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | -0.033      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.161       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.969       |
# |    value_loss           | 0.5         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 43           |
# |    iterations           | 7            |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0136304945 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | -0.0924      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.19         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0161      |
# |    std                  | 0.97         |
# |    value_loss           | 0.386        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 8           |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011130259 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | -0.227      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0341      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.952       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 9           |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014474386 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0997      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.945       |
# |    value_loss           | 0.409       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 10          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015772948 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0612      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.935       |
# |    value_loss           | 0.23        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 11         |
# |    time_elapsed         | 522        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01799726 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0187     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0209    |
# |    std                  | 0.919      |
# |    value_loss           | 0.192      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 12          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016862076 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0163      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.914       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 13          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017491648 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.9         |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 14          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016045056 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0146      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.885       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 15        |
# |    time_elapsed         | 713       |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0202382 |
# |    clip_fraction        | 0.186     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.86     |
# |    explained_variance   | 0.867     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0343    |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -0.0225   |
# |    std                  | 0.87      |
# |    value_loss           | 0.232     |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 16          |
# |    time_elapsed         | 760         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022504218 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0453      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.856       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 17          |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025339544 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0923      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.845       |
# |    value_loss           | 0.283       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 18          |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021675237 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.827       |
# |    value_loss           | 0.214       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 19          |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022659933 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0976      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.818       |
# |    value_loss           | 0.487       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 20          |
# |    time_elapsed         | 950         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020218194 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0442      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.81        |
# |    value_loss           | 0.493       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 21          |
# |    time_elapsed         | 997         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022932578 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0535      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.801       |
# |    value_loss           | 0.492       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 22          |
# |    time_elapsed         | 1045        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.024637949 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.301       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.027      |
# |    std                  | 0.792       |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 23          |
# |    time_elapsed         | 1092        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.027352614 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0574      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.78        |
# |    value_loss           | 0.541       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 24          |
# |    time_elapsed         | 1140        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.031299576 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.773       |
# |    value_loss           | 0.839       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 25          |
# |    time_elapsed         | 1187        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025423275 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.348       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.766       |
# |    value_loss           | 1.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 26          |
# |    time_elapsed         | 1235        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.029898703 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.762       |
# |    value_loss           | 0.211       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 27         |
# |    time_elapsed         | 1283       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03071565 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.145      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0249    |
# |    std                  | 0.755      |
# |    value_loss           | 0.581      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 28          |
# |    time_elapsed         | 1330        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.024427935 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.753       |
# |    value_loss           | 0.708       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 29          |
# |    time_elapsed         | 1377        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.030084029 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.742       |
# |    value_loss           | 0.958       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 30          |
# |    time_elapsed         | 1426        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.032125913 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0282     |
# |    std                  | 0.736       |
# |    value_loss           | 0.742       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 31         |
# |    time_elapsed         | 1473       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02906207 |
# |    clip_fraction        | 0.312      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.506      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 0.733      |
# |    value_loss           | 1.52       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 32          |
# |    time_elapsed         | 1520        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.047276676 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0489      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.718       |
# |    value_loss           | 0.482       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 33          |
# |    time_elapsed         | 1568        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.041577823 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.708       |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 34         |
# |    time_elapsed         | 1616       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03306803 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.884      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.34       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0247    |
# |    std                  | 0.7        |
# |    value_loss           | 1.99       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 35          |
# |    time_elapsed         | 1664        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.052896623 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.469       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.695       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 36          |
# |    time_elapsed         | 1712        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.033476196 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.522       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.691       |
# |    value_loss           | 2.03        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 37         |
# |    time_elapsed         | 1759       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.05925415 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.719      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.753      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0133    |
# |    std                  | 0.689      |
# |    value_loss           | 6.75       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 38         |
# |    time_elapsed         | 1806       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.04547998 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.491      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00872   |
# |    std                  | 0.688      |
# |    value_loss           | 3.53       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 39          |
# |    time_elapsed         | 1855        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.050095186 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.687       |
# |    value_loss           | 4.65        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 40         |
# |    time_elapsed         | 1903       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06756474 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.647      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00481    |
# |    std                  | 0.685      |
# |    value_loss           | 6.57       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 41         |
# |    time_elapsed         | 1951       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08971645 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.97       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00612    |
# |    std                  | 0.684      |
# |    value_loss           | 9.66       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 42         |
# |    time_elapsed         | 1999       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.10127081 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.78       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.0199     |
# |    std                  | 0.683      |
# |    value_loss           | 23.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 43         |
# |    time_elapsed         | 2048       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.07417783 |
# |    clip_fraction        | 0.52       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.686      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.77       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.016      |
# |    std                  | 0.683      |
# |    value_loss           | 15.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 44         |
# |    time_elapsed         | 2096       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.12818047 |
# |    clip_fraction        | 0.554      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.763      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.96       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0324     |
# |    std                  | 0.685      |
# |    value_loss           | 12.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 45         |
# |    time_elapsed         | 2143       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.12075645 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.65       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.021      |
# |    std                  | 0.687      |
# |    value_loss           | 21.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 46         |
# |    time_elapsed         | 2191       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07631604 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.42       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.023      |
# |    std                  | 0.688      |
# |    value_loss           | 18.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 47         |
# |    time_elapsed         | 2238       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.07434489 |
# |    clip_fraction        | 0.466      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0307     |
# |    std                  | 0.693      |
# |    value_loss           | 8.47       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 48         |
# |    time_elapsed         | 2285       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.19463348 |
# |    clip_fraction        | 0.58       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.854      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.3        |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0238     |
# |    std                  | 0.694      |
# |    value_loss           | 30.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 49         |
# |    time_elapsed         | 2332       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.11291808 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0437     |
# |    std                  | 0.701      |
# |    value_loss           | 15.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 50         |
# |    time_elapsed         | 2380       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.21405767 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.249      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.006     |
# |    std                  | 0.698      |
# |    value_loss           | 4.68       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 51        |
# |    time_elapsed         | 2427      |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.1850683 |
# |    clip_fraction        | 0.536     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.13     |
# |    explained_variance   | 0.919     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.56      |
# |    n_updates            | 500       |
# |    policy_gradient_loss | 0.0269    |
# |    std                  | 0.699     |
# |    value_loss           | 20.8      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 52         |
# |    time_elapsed         | 2475       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.16520074 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.664      |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0698     |
# |    std                  | 0.703      |
# |    value_loss           | 7.43       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 53         |
# |    time_elapsed         | 2524       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.17352799 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0268     |
# |    std                  | 0.706      |
# |    value_loss           | 11.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 54         |
# |    time_elapsed         | 2577       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.22386318 |
# |    clip_fraction        | 0.506      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.9        |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0332     |
# |    std                  | 0.713      |
# |    value_loss           | 10.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 55         |
# |    time_elapsed         | 2629       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.14003566 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.47       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.0311     |
# |    std                  | 0.72       |
# |    value_loss           | 15.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 56          |
# |    time_elapsed         | 2680        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.124106996 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.0243      |
# |    std                  | 0.724       |
# |    value_loss           | 16.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 57         |
# |    time_elapsed         | 2731       |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.14926988 |
# |    clip_fraction        | 0.572      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.62       |
# |    n_updates            | 560        |
# |    policy_gradient_loss | 0.0388     |
# |    std                  | 0.726      |
# |    value_loss           | 24.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 58         |
# |    time_elapsed         | 2779       |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.14635131 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.49       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0373     |
# |    std                  | 0.729      |
# |    value_loss           | 40.7       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 59        |
# |    time_elapsed         | 2827      |
# |    total_timesteps      | 120832    |
# | train/                  |           |
# |    approx_kl            | 0.1733689 |
# |    clip_fraction        | 0.564     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.26     |
# |    explained_variance   | 0.904     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.44      |
# |    n_updates            | 580       |
# |    policy_gradient_loss | 0.0461    |
# |    std                  | 0.733     |
# |    value_loss           | 17.6      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 60         |
# |    time_elapsed         | 2875       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.14777543 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.718      |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0197     |
# |    std                  | 0.74       |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 61         |
# |    time_elapsed         | 2924       |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.08808033 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.627      |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.0296     |
# |    std                  | 0.738      |
# |    value_loss           | 7.03       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 62         |
# |    time_elapsed         | 2971       |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.08860035 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# ...
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.749      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06       |
# |    n_updates            | 770        |
# |    policy_gradient_loss | 0.0381     |
# |    std                  | 0.757      |
# |    value_loss           | 8.35       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 79         |
# |    time_elapsed         | 3788       |
# |    total_timesteps      | 161792     |
# | train/                  |            |
# |    approx_kl            | 0.12439816 |
# |    clip_fraction        | 0.569      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.764      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.25       |
# |    n_updates            | 780        |
# |    policy_gradient_loss | 0.041      |
# |    std                  | 0.755      |
# |    value_loss           | 12.3       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 80        |
# |    time_elapsed         | 3837      |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.1855641 |
# |    clip_fraction        | 0.555     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.37     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.907     |
# |    n_updates            | 790       |
# |    policy_gradient_loss | 0.0177    |
# |    std                  | 0.758     |
# |    value_loss           | 8.04      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 81         |
# |    time_elapsed         | 3885       |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.12539607 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.39      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.611      |
# |    n_updates            | 800        |
# |    policy_gradient_loss | 0.0072     |
# |    std                  | 0.766      |
# |    value_loss           | 5.95       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 82         |
# |    time_elapsed         | 3933       |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.09687847 |
# |    clip_fraction        | 0.509      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.41      |
# |    explained_variance   | 0.792      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.51       |
# |    n_updates            | 810        |
# |    policy_gradient_loss | 0.0116     |
# |    std                  | 0.772      |
# |    value_loss           | 11.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 83         |
# |    time_elapsed         | 3980       |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.19972035 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08       |
# |    n_updates            | 820        |
# |    policy_gradient_loss | 0.0118     |
# |    std                  | 0.777      |
# |    value_loss           | 8.04       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 84         |
# |    time_elapsed         | 4027       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.15152612 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.23       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.0247     |
# |    std                  | 0.773      |
# |    value_loss           | 4.86       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 85         |
# |    time_elapsed         | 4076       |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.15781331 |
# |    clip_fraction        | 0.558      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.42       |
# |    n_updates            | 840        |
# |    policy_gradient_loss | 0.0276     |
# |    std                  | 0.775      |
# |    value_loss           | 13.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 86         |
# |    time_elapsed         | 4124       |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.15293954 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.689      |
# |    n_updates            | 850        |
# |    policy_gradient_loss | 0.025      |
# |    std                  | 0.773      |
# |    value_loss           | 5.76       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 87        |
# |    time_elapsed         | 4172      |
# |    total_timesteps      | 178176    |
# | train/                  |           |
# |    approx_kl            | 0.2124952 |
# |    clip_fraction        | 0.617     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.42     |
# |    explained_variance   | 0.852     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.908     |
# |    n_updates            | 860       |
# |    policy_gradient_loss | 0.0388    |
# |    std                  | 0.774     |
# |    value_loss           | 12.3      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 88         |
# |    time_elapsed         | 4220       |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.16040455 |
# |    clip_fraction        | 0.542      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.831      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.961      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | 0.032      |
# |    std                  | 0.779      |
# |    value_loss           | 9.51       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 89         |
# |    time_elapsed         | 4268       |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.20763424 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.33       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.0377     |
# |    std                  | 0.783      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 90         |
# |    time_elapsed         | 4317       |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.29351658 |
# |    clip_fraction        | 0.593      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.978      |
# |    n_updates            | 890        |
# |    policy_gradient_loss | 0.0298     |
# |    std                  | 0.774      |
# |    value_loss           | 10.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 91         |
# |    time_elapsed         | 4364       |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.09285199 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.972      |
# |    n_updates            | 900        |
# |    policy_gradient_loss | 0.0187     |
# |    std                  | 0.766      |
# |    value_loss           | 5.41       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 92         |
# |    time_elapsed         | 4412       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.12581208 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.806      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.729      |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0152     |
# |    std                  | 0.768      |
# |    value_loss           | 7.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 93         |
# |    time_elapsed         | 4461       |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.17550887 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.0225     |
# |    std                  | 0.763      |
# |    value_loss           | 5.85       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 94         |
# |    time_elapsed         | 4508       |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.14100231 |
# |    clip_fraction        | 0.548      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.969      |
# |    n_updates            | 930        |
# |    policy_gradient_loss | 0.0214     |
# |    std                  | 0.766      |
# |    value_loss           | 6.68       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 95         |
# |    time_elapsed         | 4556       |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.13345946 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.599      |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.0118     |
# |    std                  | 0.759      |
# |    value_loss           | 2.84       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 96         |
# |    time_elapsed         | 4604       |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.15385073 |
# |    clip_fraction        | 0.602      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.36       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | 0.0599     |
# |    std                  | 0.759      |
# |    value_loss           | 10.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 97         |
# |    time_elapsed         | 4652       |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.15327078 |
# |    clip_fraction        | 0.581      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.972      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | 0.0156     |
# |    std                  | 0.758      |
# |    value_loss           | 11         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 98         |
# |    time_elapsed         | 4699       |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.20407821 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.0308     |
# |    std                  | 0.762      |
# |    value_loss           | 9.96       |
# ----------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_Model')

# %%
model.save(ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env = gym.make(environment_name, render_mode='human')
evaluate_policy(model, env, n_eval_episodes=10, render=True)
